# %% [markdown]
# # 1.Check Python Version

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# # 2.Using Python as a calculator

# %% [markdown]
# ## 2.1 Arithmetic Operators

# %% [markdown]
# ### 2.1.1 Number

# %%
1
# Out:
# 1

# %% [markdown]
# ### 2.1.2 Addition

# %%
1+2
# Out:
# 3

# %% [markdown]
# ### 2.1.3 Subtraction

# %%
2-3
# Out:
# -1

# %% [markdown]
# ### 2.1.4 Multiplication

# %%
2*3
# Out:
# 6

# %% [markdown]
# ### 2.1.5 Division

# %%
3/5
# Out:
# 0.6

# %% [markdown]
# ### 2.1.6 Modulus

# %%
5%7
# Out:
# 5

# %% [markdown]
# ### 2.1.7 Exponentiation

# %%
3**4
# Out:
# 81

# %% [markdown]
# ### 2.1.8 Floor division

# %% [markdown]
# ## 2.2 Comparison Operators

# %% [markdown]
# ### 2.2.1 Equal

# %%
4==4
# Out:
# True

# %%
4==5
# Out:
# False

# %% [markdown]
# ### 2.2.2 Not equal

# %%
4!=4
# Out:
# False

# %%
4!=6
# Out:
# True

# %% [markdown]
# ### 2.2.3 Greater than

# %%
3<7
# Out:
# True

# %%
3<2
# Out:
# False

# %% [markdown]
# ### 2.2.4 Less than

# %%
2>1
# Out:
# True

# %%
33>55
# Out:
# False

# %% [markdown]
# ### 2.2.5 Greater than or equal to

# %%
3>=1
# Out:
# True

# %% [markdown]
# ### 2.2.6 Less than or equal to

# %%
4<=4
# Out:
# True

# %% [markdown]
# ## 2.3.Logical Operators

# %% [markdown]
# ### 2.3.1 or

# %%
2>1 or 4<3
# Out:
# True

# %% [markdown]
# ### 2.3.2 and

# %%
2>1 and 4<3
# Out:
# False

# %% [markdown]
# ### 2.3.3 not

# %%
not(2>1 and 4<3)
# Out:
# True

# %% [markdown]
# # 3.Print Command

# %% [markdown]
# ## 3.1 Print Strings

# %%
print(f'Hey there!')
# Out:
# Hey there!

# %% [markdown]
# ## 3.2 Single quote or Dobule quotes?

# %% [markdown]
# ## 3.3 Strings can be joined together

# %%
print("Hey there!"*3)
# Out:
# Hey there!Hey there!Hey there!

# %%
print("print there!" + " How are you?")
# Out:
# print there! How are you?

# %% [markdown]
# # 4.Comments and Variables

# %% [markdown]
# ## 4.1 Comments

# %% [markdown]
# ### 4.1.1 Single line comment

# %%
#this is comment line

# %%
print(f'Hey there!') # this is print command
# Out:
# Hey there!

# %% [markdown]
# ### 4.1.2 Multiline comment

# %%
#hi
#there

# %%
'''
Hi
There
'''
print("Hey")
# Out:
# Hey

# %% [markdown]
# ## 4.2 Variables

# %% [markdown]
# ### 4.2.1 Creating Variables

# %%
x=4.0 # x is of type int
print(x)
# Out:
# 4.0

# %%
type(x)
# Out:
# float

# %%
y='XYZ'
print(y)
# Out:
# XYZ

# %%
type(y)
# Out:
# str

# %% [markdown]
# ### 4.2.2 Casting

# %%
x=int(4.7)
y=float(4)
z=str(4)

# %%
x
# Out:
# 4

# %%
y
# Out:
# 4.0

# %%
z
# Out:
# '4'

# %% [markdown]
# ### 4.2.3 Get the Variable Type

# %%
type(z)
# Out:
# str

# %% [markdown]
# ### 4.2.4 They are Case-Sensitive

# %%
x=4
X=5

# %%
x
# Out:
# 4

# %%
X
# Out:
# 5

# %% [markdown]
# ### 4.2.5 Assign Multiple Values

# %%
x=y=z='Hey there'
print(x)
# Out:
# Hey there

# %%
x,y=2,3

# %%
x
# Out:
# 2

# %%
y
# Out:
# 3

# %% [markdown]
# ### 4.2.6 Print both string and variable

# %%
L=['Apple','Boy','Cat']
x,y,z=L

# %%
x
# Out:
# 'Apple'

# %%
y
# Out:
# 'Boy'

# %%
z
# Out:
# 'Cat'

# %% [markdown]
# # 5.List, Tuple, Set and Dictionaries

# %% [markdown]
# ## 5.1 List (or Array)

# %% [markdown]
# ### 5.1.1 Basics

# %%
x=[]

# %%
x
# Out:
# []

# %%
y=[1,2,3]

# %%
y
# Out:
# [1, 2, 3]

# %%
type(y)
# Out:
# list

# %%
y*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
len(y)
# Out:
# 3

# %% [markdown]
# ### 5.1.2 Positions & Modify element in list

# %%
y=[1,2,3,4,5,6,7]

# %%
y[2] #it will give third item of the y list
# Out:
# 3

# %%
y[-1]
# Out:
# 7

# %%
y[:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
y[3:6]
# Out:
# [4, 5, 6]

# %%
y[2]=8
y
# Out:
# [1, 2, 8, 4, 5, 6, 7]

# %%
y.append(77)
y
# Out:
# [1, 2, 8, 4, 5, 6, 7, 77]

# %%
y.insert(1,77)
y
# Out:
# [1, 77, 2, 8, 4, 5, 6, 7, 77]

# %%
x=[1,2,3]
y=[4,5,6]
x.extend(y)
x
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
y=[1,2,6,7,3,4]
y.remove(3)
y
# Out:
# [1, 2, 6, 7, 4]

# %%
y=[1,3,4,5,2]
x=y
del y[2:4]
print(x)
# Out:
# [1, 3, 2]

# %%
y=[1,2,6,7,2,3,4]
x=y
y.pop(3)
print(x)
# Out:
# [1, 2, 6, 2, 3, 4]
